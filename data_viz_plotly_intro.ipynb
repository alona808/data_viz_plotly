# %% [markdown]
# <a href="https://colab.research.google.com/github/alona808/data_viz_plotly/blob/master/data_viz_plotly_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datacamp course: Introduction to Data Visualization with Plotly in Python
# https://app.datacamp.com/learn/courses/introduction-to-data-visualization-with-plotly-in-python

# %% [markdown]
# ## Import modules

# %%
import os
import pandas as pd
import random
import calendar
calendar.setfirstweekday(calendar.SUNDAY)

# visualization
import plotly.express as px
from plotly.subplots import make_subplots
# from plotly.offline import iplot
from plotly.graph_objects import Figure

# connect to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Additional settings

# %%
# !pip install --upgrade jupyterlab plotly

# %%
# To display the full text of a pandas DataFrame
pd.set_option('display.max_colwidth', 1)

# To display all columns of DataFrame
pd.set_option('display.max_columns', None)

# To print all the outputs in the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# To show warnings only once:
import warnings; warnings.filterwarnings(action='once')

# %% [markdown]
# File path to data sets

# %%
path_to_raw_data = '/content/drive/My Drive/colab_notebooks/data_viz_plotly/data/'
file_penguins = 'penguins.csv'
file_monthly_sales = 'monthly_sales.csv'
file_AAPL = 'AAPL.csv'
file_rain = 'rain.csv'
file_revenue_data = 'revenue_data.csv'
file_revenue_data2 = 'revenue_data2.csv'
file_world_bank_population = 'world_bank_population.csv'

# %% [markdown]
# ##Plotly basic bar chart

# %%
# Get calendar days
days = ['Sunday', 'Monday', 'Tuesday', 'Wednsday', 'Thursday', 'Friday', 'Saturday']

full_weekdays = list(calendar.day_name)
abbr_weekdays = list(calendar.day_abbr)

# day_names = list(calendar.day_name)
# weekdays = [calendar.day_name[i] for i in range(7)]

days
full_weekdays
abbr_weekdays
# day_names
# weekdays
# Out:
# ['Sunday', 'Monday', 'Tuesday', 'Wednsday', 'Thursday', 'Friday', 'Saturday']
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
# Generate a random temperature between 20 and 37 degrees Celsius
min_temp = 18
max_temp = 39
num_tempr = 7

temperature = [
    # random.uniform(min_temp, max_temp) for _ in range(num_tempr)
    random.randint(min_temp, max_temp) for _ in range(num_tempr)
]

temperature
# Out:
# [24, 31, 23, 30, 34, 37, 18]

# %%
# plot graph
fig = px.bar(
    x=abbr_weekdays
    ,y=temperature
    ,title='Temperatures of week'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="5ec5a8d8-bf5d-4995-947d-40f9a4bf8fa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5ec5a8d8-bf5d-4995-947d-40f9a4bf8fa2")) {                    Plotly.newPlot(                        "5ec5a8d8-bf5d-4995-947d-40f9a4bf8fa2",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":{"dtype":"i1","bdata":"GB8XHiIlEg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line" ...

# %% [markdown]
# The plotly figure elements

# %%
print(fig)
# Out:
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'GB8XHiIlEg==', 'dtype': 'i1'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Temperatures of week'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %% [markdown]
# ## <mark>Univariate plots:</mark>
# - Bar chart
# - Box p;ot
# - Density plots

# %% [markdown]
# ###Load penguins data

# %%
penguins = pd.read_csv(os.path.join(path_to_raw_data, file_penguins))
                            #  ,encoding='ISO-8859-1') # or use that: encoding='cp1252'

df_penguins = penguins.copy()

# %%
df_penguins.info()
df_penguins.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           344 non-null    int64
#  1   studyName            344 non-null    object
#  2   Sample Number        344 non-null    int64
#  3   Species              344 non-null    object
#  4   Region               344 non-null    object
#  5   Island               344 non-null    object
#  6   Stage                344 non-null    object
#  7   Individual ID        344 non-null    object
#  8   Clutch Completion    344 non-null    object
#  9   Date Egg             344 non-null    object
#  10  Culmen Length (mm)   342 non-null    float64
#  11  Culmen Depth (mm)    342 non-null    float64
#  12  Flipper Length (mm)  342 non-null    float64
#  13  Body Mass (g)        342 non-null    float64
#  14  Sex                  333 non-null    object
#  15  Delta 15 N (o/oo)    330 non-null    float64
#  16  Delta 13 C (o/oo)    331 non-null    float64
#  17  Comments             54 non-null     object
# dtypes: float64(6), int64(2), object(10)
# memory usage: 48.5+ KB
#    Unnamed: 0 studyName  Sample Number                              Species  \
# 0  1           PAL0708   1              Adelie Penguin (Pygoscelis adeliae)
# 1  2           PAL0708   2              Adelie Penguin (Pygoscelis adeliae)
# 2  3           PAL0708   3              Adelie Penguin (Pygoscelis adeliae)
# 3  4           PAL0708   4              Adelie Penguin (Pygoscelis adeliae)
# 4  5           PAL0708   5              Adelie Penguin (Pygoscelis adeliae)
#
#    Region     Island               Stage Individual ID Clutch Completion  \
# 0  Anvers  Torgersen  Adult, 1 Egg Stage  N1A1          Yes
# 1  Anvers  Torgersen  Adult, 1 Egg Stage  N1A2          Yes
# 2  Anvers  Torgersen  Adult, 1 Egg Stage  N2A1          Yes
# 3  Anvers  Torgersen  Adult, 1 Egg Stage  N2A2          Yes
# 4  Anvers  Torgersen  Adult, 1 Egg Stage  N3A1          Yes
#
#      Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0  2007-11-11  39.1                18.7               181.0
# 1  2007-11-11  39.5                17.4               186.0
# 2  2007-11-16  40.3                18.0               195.0
# 3  2007-11-16 NaN                 NaN                NaN
# 4  2007-11-16  36.7                19.3               193.0
#
#    Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0  3750.0         MALE   NaN                NaN
# 1  3800.0         FEMALE  8.94956           -24.69454
# 2  3250.0         FEMALE  8.36821           -25.33302
# 3 NaN             NaN    NaN                NaN
# 4  3450.0         FEMALE  8.76651           -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1  NaN
# 2  NaN
# 3  Adult not sampled.
# 4  NaN

# %%
df_penguins.describe()
# Out:
#        Unnamed: 0  Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count  344.000000  344.000000     342.000000          342.000000
# mean   172.500000  63.151163      43.921930           17.151170
# std    99.448479   40.430199      5.459584            1.974793
# min    1.000000    1.000000       32.100000           13.100000
# 25%    86.750000   29.000000      39.225000           15.600000
# 50%    172.500000  58.000000      44.450000           17.300000
# 75%    258.250000  95.250000      48.500000           18.700000
# max    344.000000  152.000000     59.600000           21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count  342.000000           342.000000     330.000000
# mean   200.915205           4201.754386    8.733382
# std    14.061714            801.954536     0.551770
# min    172.000000           2700.000000    7.632200
# 25%    190.000000           3550.000000    8.299890
# 50%    197.000000           4050.000000    8.652405
# 75%    213.000000           4750.000000    9.172123
# max    231.000000           6300.000000    10.025440
#
#        Delta 13 C (o/oo)
# count  331.000000
# mean  -25.686292
# std    0.793961
# min   -27.018540
# 25%   -26.320305
# 50%   -25.833520
# 75%   -25.062050
# max   -23.787670

# %%
# df_penguins.columns = df_penguins.columns.str.lower()

# %%
# df_penguins.columns = [columns.replace(' ', '_').replace('(', '').replace(')', '') for columns in df_penguins.columns]
# df_penguins.sample(5)

# %% [markdown]
# ### Histograms
# https://plotly.com/python/histograms/

# %%
fig = px.histogram(
    df_penguins
    ,x='Body Mass (g)'
    ,nbins=10
    ,title=f'Histogram of Penguins Body Mass (g)'
    # ,orientation='h' ?
    ,histfunc='max'
    ,hover_data=df_penguins.columns
    ,color="Sex"
    ,text_auto=True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="ed9decbd-389f-401c-bf33-a707d31f1307" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ed9decbd-389f-401c-bf33-a707d31f1307")) {                    Plotly.newPlot(                        "ed9decbd-389f-401c-bf33-a707d31f1307",                        [{"bingroup":"x","histfunc":"max","hovertemplate":"Sex=MALE\u003cbr\u003eBody Mass (g)=%{x}\u003cbr\u003emax of None=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MALE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"MALE","nbinsx":10,"orientation":"v","showlegend":true,"texttemplate":"%{value}","x":{"dtype":"f8","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","histfunc":"max","hovertemplate":"Sex=FEMALE\u003cbr\u003eBody Mass (g)=%{x}\u003cbr\u003emax of None=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FEMALE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"FEMALE","nbinsx":10,"orientation":"v","showlegend":true,"texttemplate":"%{value}","x":{"dtype":"f8","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay", ...

# %% [markdown]
# ###Box (and whisker) plots
# https://plotly.com/python/box-plots/

# %%
df_penguins.columns
# Out:
# Index(['Unnamed: 0', 'studyName', 'Sample Number', 'Species', 'Region',
#        'Island', 'Stage', 'Individual ID', 'Clutch Completion', 'Date Egg',
#        'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
#        'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)',
#        'Comments'],
#       dtype='object')

# %%
fig = px.box(
    df_penguins
    ,y='Flipper Length (mm)'
    ,title=f'Box plot of of Penguins Flipper Length (mm)'
    # ,orientation='h' ?
    ,hover_data=df_penguins.columns
    ,color="Sex"
    ,points="all"
    # ,notched=True, # used notched shape
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="49219bd2-418e-4604-ad87-4ae563e30571" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("49219bd2-418e-4604-ad87-4ae563e30571")) {                    Plotly.newPlot(                        "49219bd2-418e-4604-ad87-4ae563e30571",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[1,"PAL0708",1,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N1A1","Yes","2007-11-11",39.1,18.7,3750.0,"MALE",null,null,"Not enough blood for isotopes."],[6,"PAL0708",6,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N3A2","Yes","2007-11-16",39.3,20.6,3650.0,"MALE",8.66496,-25.29805,null],[8,"PAL0708",8,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N4A2","No","2007-11-15",39.2,19.6,4675.0,"MALE",9.4606,-24.89958,"Nest never observed with full clutch."],[14,"PAL0708",14,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N7A2","Yes","2007-11-15",38.6,21.2,3800.0,"MALE",null,null,"Not enough blood for isotopes."],[15,"PAL0708",15,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N8A1","Yes","2007-11-16",34.6,21.1,4400.0,"MALE",8.55583,-25.22588,null],[18,"PAL0708",18,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N9A2","Yes","2007-11-12",42.5,20.7,4500.0,"MALE",8.67538,-25.13993,null],[20,"PAL0708",20,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Torgersen","Adult, 1 Egg Stage","N10A2","Yes","2007-11-16",46.0,21.5,4200.0,"MALE",9.11616,-24.77227,null],[22,"PAL0708",22,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Biscoe","Adult, 1 Egg Stage","N11A2","Yes","2007-11-12",37.7,18.7,3600.0,"MALE",8.66271,-25.0639,null],[24,"PAL0708",24,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Biscoe","Adult, 1 Egg Stage","N12A2","Yes","2007-11-12",38.2,18.1,3950.0,"MALE",8.43423,-25.22664,null],[25,"PAL0708",25,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Biscoe","Adult, 1 Egg Stage","N13A1","Yes","2007-11-10",38.8,17.2,3800.0,"MALE",9.63954,-25.29856,null],[27,"PAL0708",27,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Biscoe","Adult, 1 Egg Stage","N17A1","Yes","2007-11-12",40.6,18.6,3550.0,"MALE",8.93997,-25.36288,null],[30,"PAL0708",30,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Biscoe","Adult, 1 Egg Stage","N18A2","No","2007-11-10",40.5,18.9,3950.0,"MALE",8.90027,-25.11609,"Nest never observed with full clutch."],[32,"PAL0708",32,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Stage","N21A2","Yes","2007-11-09",37.2,18.1,3900.0,"MALE",9.72764,-25.0102,null],[34,"PAL0708",34,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Stage","N22A2","Yes","2007-11-09",40.9,18.9,3900.0,"MALE",8.79665,-25.14591,null],[36,"PAL0708",36,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Stage","N23A2","Yes","2007-11-16",39.2,21.1,4150.0,"MALE",9.15308,-25.03469,null],[37,"PAL0708",37,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Stage","N24A1","Yes","2007-11-16",38.8,20.0,3950.0,"MALE",9.18985,-25.12255,null],[40,"PAL0708",40,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Stage","N25A2","No","2007-11-13",39.8,19.1,4650.0,"MALE",null,null,"Nest never observed with full clutch. Not enough blood for isotopes."],[42,"PAL0708",42,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Stage","N26A2","Yes","2007-11-16",40.8,18.4,3900.0,"MALE",null,null,"Not enough blood for isotopes."],[44,"PAL0708",44,"Adelie Penguin (Pygoscelis adeliae)","Anvers","Dream","Adult, 1 Egg Sta ...

# %% [markdown]
# ###Specific colors in plotly.express

# %%
# plot graph
fig = px.bar(
    x=abbr_weekdays
    ,y=temperature
    ,title='Temperatures of week'
    ,color_discrete_map={
        'Mon': 'rgb(0.0.128)'
        ,'Wed': 'rgb(235,207,52)'
    }
    # ,color=temperature
    ,height=400
    ,width=600
    # ,labels={'temperature': ''} ?
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="7a566636-b8d1-4a92-89f7-81c488a6302c" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7a566636-b8d1-4a92-89f7-81c488a6302c")) {                    Plotly.newPlot(                        "7a566636-b8d1-4a92-89f7-81c488a6302c",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":{"dtype":"i1","bdata":"GB8XHiIlEg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line ...

# %%
# plot graph
fig = px.bar(
    x=abbr_weekdays
    ,y=temperature
    ,title='Temperatures of week'
    ,color=temperature
    ,height=400
    ,width=600
    # ,labels={'temperature': ''} ?
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="93e94576-bed5-4b06-8804-f3e42b6d3636" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("93e94576-bed5-4b06-8804-f3e42b6d3636")) {                    Plotly.newPlot(                        "93e94576-bed5-4b06-8804-f3e42b6d3636",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i1","bdata":"GB8XHiIlEg=="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":{"dtype":"i1","bdata":"GB8XHiIlEg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","mark ...

# %%
my_scale=[
    ('rgb(242,238,10)')
    ,('rgb(242,95,10)')
    ,('rgb(255,0,0)')
]

# %%
# plot graph
fig = px.bar(
    x=abbr_weekdays
    ,y=temperature
    ,title='Temperatures of week'
    # ,color_descrete_map={
    #     'Mon': 'rgb(0.0.128)'
    #     ,'Wen': 'rgb(235,207,52)'
    # }
    ,color_continuous_scale=my_scale
    ,color=temperature
    ,height=400
    ,width=600
    # ,labels={'temperature': ''} ?
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="d0e8df6d-6af8-4f2b-9523-98139ff50814" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d0e8df6d-6af8-4f2b-9523-98139ff50814")) {                    Plotly.newPlot(                        "d0e8df6d-6af8-4f2b-9523-98139ff50814",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i1","bdata":"GB8XHiIlEg=="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":{"dtype":"i1","bdata":"GB8XHiIlEg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","mark ...

# %% [markdown]
# ## <mark>Bivariate visualizations</mark>
#
# Some examples:
# - Scatterplots
# - Line charts
# - Correlation plots

# %%
df_penguins.columns
# Out:
# Index(['Unnamed: 0', 'studyName', 'Sample Number', 'Species', 'Region',
#        'Island', 'Stage', 'Individual ID', 'Clutch Completion', 'Date Egg',
#        'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
#        'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)',
#        'Comments'],
#       dtype='object')

# %%
df_penguins = df_penguins.astype(
    {'Sample Number': 'int'
    # ,'Date Egg': 'pd.to_datetime('Date Egg')})
    ,'Culmen Length (mm)': 'float'
    ,'Culmen Depth (mm)': 'float'
    ,'Flipper Length (mm)': 'float'
    ,'Body Mass (g)': 'float'

    })

# %%
# df_penguins.sample(5)

# %% [markdown]
# ### Scatter plot

# %%
# Create a scatterplot
fig = px.scatter(data_frame=penguins, title="Penguin Culmen Statistics",
    # Set the right columns
    x="Culmen Length (mm)",
    y="Culmen Depth (mm)",
    # We will set some colors
    color="Species",
    # color_discrete_map=color_map
)

# Show your work
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c1b916ed-f0a8-445c-bd7c-663765914df8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c1b916ed-f0a8-445c-bd7c-663765914df8")) {                    Plotly.newPlot(                        "c1b916ed-f0a8-445c-bd7c-663765914df8",                        [{"hovertemplate":"Species=Adelie Penguin (Pygoscelis adeliae)\u003cbr\u003eCulmen Length (mm)=%{x}\u003cbr\u003eCulmen Depth (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adelie Penguin (Pygoscelis adeliae)","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Adelie Penguin (Pygoscelis adeliae)","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMyMQ0AAAAAAAMBDQGZmZmZmJkRAAAAAAAAA+H+amZmZmVlCQGZmZmZmpkNAMzMzMzNzQ0CamZmZmZlDQM3MzMzMDEFAAAAAAAAARUBmZmZmZuZCQGZmZmZm5kJAzczMzMyMREDNzMzMzExDQM3MzMzMTEFAzczMzMxMQkCamZmZmVlDQAAAAAAAQEVAMzMzMzMzQUAAAAAAAABHQGZmZmZm5kJAmpmZmZnZQkAzMzMzM\u002fNBQJqZmZmZGUNAZmZmZmZmQ0BmZmZmZqZBQM3MzMzMTERAAAAAAABAREAzMzMzM\..."},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzOzMkBmZmZmZmYxQAAAAAAAADJAAAAAAAAA+H\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Species=Gentoo penguin (Pygoscelis papua)\u003cbr\u003eCulmen Length (mm)=%{x}\u003cbr\u003eCulmen Depth (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gentoo penguin (Pygoscelis papua)","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Gentoo penguin (Pygoscelis papua)","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"...\u002fZmZmZmZmR0AzMzMzMzNJQJqZmZmZmUZAMzMzMzPzSEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002fmpmZmZmZLEBmZmZmZmYvQJqZmZmZmS1AmpmZmZkZMEA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Species=Chinstrap penguin (Pygoscelis antarctica)\u003cbr\u003eCulmen Length (mm)=%{x}\u003cbr\u003eCulmen Depth (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinstrap penguin (Pygoscelis antarctica)","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Chinstrap penguin (Pygoscelis antarctica)","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#460 ...

# %% [markdown]
# ##<mark>Customizing Plots</mark>

# %% [markdown]
# ### Update Axis

# %%
_df_penguins = df_penguins.groupby(['Species'])['Flipper Length (mm)'].mean().round(2).reset_index()
_df_penguins
# Out:
#                                      Species  Flipper Length (mm)
# 0  Adelie Penguin (Pygoscelis adeliae)        189.95
# 1  Chinstrap penguin (Pygoscelis antarctica)  195.82
# 2  Gentoo penguin (Pygoscelis papua)          217.19

# %%
# Create the plot
fig = px.bar(_df_penguins,
             x="Species",
             y="Flipper Length (mm)",
             title="Flipper Length (mm) by Species",
             color="Species")

# Change the axis titles
fig.update_layout(
    xaxis=dict(title=dict(text="Species")),
    yaxis=dict(title=dict(text="Average Flipper Length (mm)"))
)

# Show the plot
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="33bc3047-9427-44fd-8415-8287954a38de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("33bc3047-9427-44fd-8415-8287954a38de")) {                    Plotly.newPlot(                        "33bc3047-9427-44fd-8415-8287954a38de",                        [{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adelie Penguin (Pygoscelis adeliae)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Adelie Penguin (Pygoscelis adeliae)","orientation":"v","showlegend":true,"textposition":"auto","x":["Adelie Penguin (Pygoscelis adeliae)"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZma+Z0A="},"yaxis":"y","type":"bar"},{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinstrap penguin (Pygoscelis antarctica)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Chinstrap penguin (Pygoscelis antarctica)","orientation":"v","showlegend":true,"textposition":"auto","x":["Chinstrap penguin (Pygoscelis antarctica)"],"xaxis":"x","y":{"dtype":"f8","bdata":"CtejcD16aEA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gentoo penguin (Pygoscelis papua)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Gentoo penguin (Pygoscelis papua)","orientation":"v","showlegend":true,"textposition":"auto","x":["Gentoo penguin (Pygoscelis papua)"],"xaxis":"x","y":{"dtype":"f8","bdata":"rkfhehQma0A="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %% [markdown]
# ### Annotating your savings
#
# Using `add_annotation()` adds a single annotationUsing
#
# `update_layout()` and the annotations argumentAccepts a list of annotation objects
#
# `showarrow = True/False` - used to include an arrowThe arrow can be customized

# %%
# Create the first annotation
min_avg = dict(
    x=0, y=200, text="Adelie Penguin has the minimum average length",
    font=dict(color="black"), showarrow=True, arrowhead=4
)

# Create the second annotation
max_avg = dict(
    x=2, y=220, text="Gentoo penguin has the maximum average length",
    font=dict(color="black"), showarrow=True, arrowhead=4,
)

# Add annotations to the figure
fig.update_layout(annotations=[min_avg, max_avg])

# Show the plot
fig.show(); # Add a semicolon here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="31ef7459-dc4f-43c4-a5e2-aa78405a123e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("31ef7459-dc4f-43c4-a5e2-aa78405a123e")) {                    Plotly.newPlot(                        "31ef7459-dc4f-43c4-a5e2-aa78405a123e",                        [{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adelie Penguin (Pygoscelis adeliae)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Adelie Penguin (Pygoscelis adeliae)","orientation":"v","showlegend":true,"textposition":"auto","x":["Adelie Penguin (Pygoscelis adeliae)"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZma+Z0A="},"yaxis":"y","type":"bar"},{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinstrap penguin (Pygoscelis antarctica)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Chinstrap penguin (Pygoscelis antarctica)","orientation":"v","showlegend":true,"textposition":"auto","x":["Chinstrap penguin (Pygoscelis antarctica)"],"xaxis":"x","y":{"dtype":"f8","bdata":"CtejcD16aEA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gentoo penguin (Pygoscelis papua)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Gentoo penguin (Pygoscelis papua)","orientation":"v","showlegend":true,"textposition":"auto","x":["Gentoo penguin (Pygoscelis papua)"],"xaxis":"x","y":{"dtype":"f8","bdata":"rkfhehQma0A="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
# Get and format today's date
# today = datetime.today().strftime("%A")

# Create the message_annotation
message_annotation = dict(
  # Set the correct coordinates
  x=0.5, y=0.95, xref="paper", yref="paper",
  # Set the format of the text and box
  text=f"Let's know an average length of penguins :)",
  font=dict(size=20, color="white"),
  bgcolor="rgb(227, 88, 200)", showarrow=False
)

# Update the figure layout and show
fig.update_layout(annotations=[message_annotation])
# fig.update_layout(annotations=[min_avg, max_avg, message_annotation])


fig.show(); # Add a semicolon here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="7cbeaf85-f6e5-4497-b830-3bd40bb42e90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7cbeaf85-f6e5-4497-b830-3bd40bb42e90")) {                    Plotly.newPlot(                        "7cbeaf85-f6e5-4497-b830-3bd40bb42e90",                        [{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adelie Penguin (Pygoscelis adeliae)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Adelie Penguin (Pygoscelis adeliae)","orientation":"v","showlegend":true,"textposition":"auto","x":["Adelie Penguin (Pygoscelis adeliae)"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZma+Z0A="},"yaxis":"y","type":"bar"},{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinstrap penguin (Pygoscelis antarctica)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Chinstrap penguin (Pygoscelis antarctica)","orientation":"v","showlegend":true,"textposition":"auto","x":["Chinstrap penguin (Pygoscelis antarctica)"],"xaxis":"x","y":{"dtype":"f8","bdata":"CtejcD16aEA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Species=%{x}\u003cbr\u003eFlipper Length (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gentoo penguin (Pygoscelis papua)","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Gentoo penguin (Pygoscelis papua)","orientation":"v","showlegend":true,"textposition":"auto","x":["Gentoo penguin (Pygoscelis papua)"],"xaxis":"x","y":{"dtype":"f8","bdata":"rkfhehQma0A="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %% [markdown]
# ## <mark>Advanced Customization</mark>

# %% [markdown]
# ### Subplots

# %%
revenue_data = pd.read_csv(os.path.join(path_to_raw_data, file_revenue_data))

df_revenue = revenue_data.copy()

# %%
df_revenue.head()
# Out:
#    Rank                   Company   Revenue
# 0  1     Walmart                   523964.0
# 1  2     Sinopec Group             407009.0
# 2  3     State Grid                383906.0
# 3  4     China National Petroleum  379130.0
# 4  5     Royal Dutch Shell         352106.0

# %%
# Create a subplot grid
fig = make_subplots(rows=2, cols=1,
                    # Set the subplot titles
                    subplot_titles=['Revenue Histogram', 'Revenue Boxplot'])

# Create plotly express figures
hist = px.histogram(df_revenue, x='Revenue')
box = px.box(df_revenue, x='Revenue')

# Extract traces and add to subplots
fig.add_trace(hist.data[0], row=1, col=1)
fig.add_trace(box.data[0], row=2, col=1)


# Add a plot title
fig.update_layout(dict(title=dict(text='Company Revenue', x=0.5, y=0.9)))

fig.show(); # Add a semicolon here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="9ba93c3a-99bc-4d95-ba78-48ef4c3e5045" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9ba93c3a-99bc-4d95-ba78-48ef4c3e5045")) {                    Plotly.newPlot(                        "9ba93c3a-99bc-4d95-ba78-48ef4c3e5045",                        [{"bingroup":"x","hovertemplate":"Revenue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002f0AAAAAAMLn+QAAAAADQeP5AAAAAAMBZ\u002fkAAAAAAwBv+QAAAAADg2v1AAAAAAHDN\u002fUAAAAAAAF\u002f9QAAAAADgXv1AAAAAAJDP\u002fEAAAAAA4Hn8QAAAAADQ+\u002ftAAAAAAFC7+0AAAAAAEOn6QAAAAACw1fpAAAAAAHC\u002f+kAAAAAAgLj6QAAAAADgmPpAAAAAAPCI+kAAAAAA8H76QAAAAAAQ3PlAAAAAAMCg+UAAAAAAUHH5QAAAAACwXvlAAAAAAJBB+UAAAAAAkBT5QAAAAACgivhAAAAAABAX+EAAAAAAEOn3QAAAAAAA0PdAAAAAAJCD90AAAAAA4D73QAAAAACAN\u002fdAAAAAAGAi90AAAAAAgOL2QAAAAACgf\u002fZAAAAAALB89kAAAAAA8C72QAAAAABAJ\u002fZAAAAAAHAf9kAAAAAAcAH2QAAAAAAw8\u002fVAAAAAAPDi9UAAAAAAkNT1QAAAAAAw0PVAAAAAAOCx9UAAAAAAUJL1QAAAAAAQjPVAAAAAAABZ9UAAAAAA4Dz1QAAAAADgD\u002fVAAAAAADAJ9UAAAAAAEPn0QAAAAAAgxPRAAAAAABCF9EAAAAAAsGv0QAAAAAAQY\u002fRAAAAAAMAw9EAAAAAAsAj0QAAAAACgA\u002fRAAAAAAPCv80AAAAAAwKzzQAAAAAAgp\u002fNAAAAAAICf80AAAAAAYJnzQAAAAADAg\u002fNAAAAAAMB680AAAAAAkGnzQAAAAAAwYvNAAAAAACBF80AAAAAAMELzQAAAAAAAEvNAAAAAALDV8kAAAAAAYM\u002fyQAAAAADQsvJAAAAAAPCw8kAAAAAAQIzyQAAAAACQh\u002fJAAAAAAABl8kAAAAAAUFfyQAAAAACwVvJAAAAAAPA48kAAAAAAIBvyQAAAAADgFvJAAAAAAAAU8kAAAAAAQPvxQAAAAADg3PFAAAAAAEDH8UAAAAAAoLbxQAAAAACQtfFAAAAAAFCd8UAAAAAAQJ3xQAAAAADQkfFAAAAAAACH8UAAAAAA4HTxQAAAAAAgX\u002fFAAAAAAPBO8UAAAAAAMETxQAAAAACQQvFAAAAAACBC8UAAAAAAcD3xQAAAAADwK\u002fFAAAAAANAD8UAAAAAAQP\u002fwQAAAAAAg\u002fPBAAAAAAODn8EAAAAAAcODwQAAAAAAQ0vBAAAAAAKDG8EAAAAAAII\...\u002f60AAAAAAACXrQAAAAACAwOpAAAAAAACy6kAAAAAAoKrqQAAAAAAgmOpAAAAAAKCL6kAAAAAAAAD4fw=="},"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"Revenue=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002f0AAAAAAMLn+QAAAAADQeP5AAAAAAMBZ\u002fkAAAAAAwBv+QAAAAADg2v1AAAAAAHDN\u002fUAAAAAAAF\u002f9QAAAAADgXv1AAAAAAJDP\u002fEAAAAAA4Hn8QAAAAADQ+\u002ftAAAAAAFC7+0AAAAAAEOn6QAAAAACw1fpAAAAAAHC\u002f+kAAAAAAgLj6QAAAAADgmPpAAAAAAPCI+kAAAAAA8H76QAAAAAAQ3PlAAAAAAMCg+UAAAAAAUHH5QAAAAACwXvlAAAAAAJBB+UAAAAAAkBT5QAAAAACgivhAAAAAABAX+EAAAAAAEOn3QAAAAAAA0PdAAAAAAJCD90AAAAAA4D73QAAAAACAN\u002fdAAAAAAGAi90AAAAAAgOL2QAAAAACgf\u002fZAAAAAALB89kAAAAAA8C72QAAAAABAJ\u002fZAAAAAAHAf9kAAAAAAcAH2QAAAAAAw8\u002fVAAAAAAPDi9UAAAAAAkNT1QAAAAAAw0PVAAAAAAOCx9UAAAAAAUJL1QAAAAAAQjPVAAAAAAABZ9UAAAAAA4Dz1QAAAAADgD\u002fVAAAAAADAJ9UAAAAAAEPn0QAAAAAAgxPRAAAAAABCF9EAAAAAAsGv0QAAAAAAQY\u002fRAAAAAAMAw9EAAAAAAsAj0QAAAAACgA\u002fRAAAAAAPCv80AAAAAAwKzzQAAAAAAgp\u002fNAAAAAAICf80AAAAAAYJnzQAAAAADAg\u002fNAAAAAAMB680AAAAAAkGnzQAAAAAAwYvNAAAAAACBF80AAAAAAMELzQAAAAAAAEvNAAAAAALDV8kAAAAAAYM\u002fyQAAAAADQsvJAAAAAAPCw8kAAAAAAQIzyQAAAAACQh\u002fJAAAAAAABl8kAAAAAAUFfyQAAAAACwVvJAAAAAAPA48kAAAAAAIBvyQAAAAADgFvJAAAAAAAAU8kAAAAAAQPvxQAAAAADg3PFAAAAAAEDH8UAAAAAAoLbxQAAAAACQtfFAAAAAAFCd8UAAAAAAQJ3xQAAAAADQkfFAAAAAAACH8UAAAAAA4HTxQAAAAAAgX\u002fFAAAAAAPBO8UAAAAAAMETxQAAAAACQQvFAAAAAACBC8UAAAAAAcD3xQAAAAADwK\u002fFAAAAAANAD8UAAAAAAQP\u002fwQAAAAAAg\u002fPBAAAAAAODn8EAAAAAAcODwQAAAAAAQ0vBAAAAAAKDG8EAAAAAAII\...\u002f60AAAAAAACXrQAAAAACAwOpAAAAAAACy6kAAAAAAoKrqQAAAAAAgmOpAAAAAAKCL6kAAAAAAAAD4fw=="},"x0":" ","xaxis":"x2","y0":" ","yaxis":"y2","type":"box"}],                        {"templ ...

# %% [markdown]
# ### Stacked subplots

# %%
df_penguins.sample(5)
# Out:
#      Unnamed: 0 studyName  Sample Number                              Species  \
# 231  232         PAL0809   80             Gentoo penguin (Pygoscelis papua)
# 234  235         PAL0910   83             Gentoo penguin (Pygoscelis papua)
# 202  203         PAL0809   51             Gentoo penguin (Pygoscelis papua)
# 241  242         PAL0910   90             Gentoo penguin (Pygoscelis papua)
# 28   29          PAL0708   29             Adelie Penguin (Pygoscelis adeliae)
#
#      Region  Island               Stage Individual ID Clutch Completion  \
# 231  Anvers  Biscoe  Adult, 1 Egg Stage  N60A2         Yes
# 234  Anvers  Biscoe  Adult, 1 Egg Stage  N6A1          Yes
# 202  Anvers  Biscoe  Adult, 1 Egg Stage  N13A1         Yes
# 241  Anvers  Biscoe  Adult, 1 Egg Stage  N14A2         Yes
# 28   Anvers  Biscoe  Adult, 1 Egg Stage  N18A1         No
#
#        Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 231  2008-11-09  45.2                16.4               223.0
# 234  2009-11-15  47.4                14.6               212.0
# 202  2008-11-04  46.6                14.2               210.0
# 241  2009-11-25  52.1                17.0               230.0
# 28   2007-11-10  37.9                18.6               172.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 231  5950.0         MALE    8.19749           -26.65931
# 234  4725.0         FEMALE  8.19101           -26.24369
# 202  4850.0         FEMALE  8.38289           -26.86352
# 241  5550.0         MALE    8.27595           -26.11657
# 28   3150.0         FEMALE  8.38404           -25.19837
#
#                                   Comments
# 231  NaN
# 234  NaN
# 202  NaN
# 241  NaN
# 28   Nest never observed with full clutch.

# %%
fig = make_subplots(rows=3, cols=1,
                    shared_xaxes=True,
                    subplot_titles=['Adelie Penguins'  , 'Gentoo Penguins', 'Chinstrap Penguins'])
row_num = 1
for species in ['Adelie', 'Gentoo', 'Chinstrap']:
  # Filter data for this species
  df = df_penguins[df_penguins['Island'] == 'Biscoe']
  scatter = px.scatter(df, x='Culmen Length (mm)'  , y='Culmen Depth (mm)')
  # Add the trace to the subplot
  fig.add_trace(scatter.data[0], row=row_num, col=1)
  row_num +=1
fig.show(); # Add a semicolon here
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c41f0bf9-a085-4bab-9845-3ed8cd222103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c41f0bf9-a085-4bab-9845-3ed8cd222103")) {                    Plotly.newPlot(                        "c41f0bf9-a085-4bab-9845-3ed8cd222103",                        [{"hovertemplate":"Culmen Length (mm)=%{x}\u003cbr\u003eCulmen Depth (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002fNLQJqZmZmZmUdAzczMzMyMSEBmZmZmZqZHQGZmZmZmZkdAmpmZmZnZREAzMzMzM7NKQGZmZmZmpkVAzczMzMwMSEAAAAAAAEBJQGZmZmZm5khAAAAAAADARUAAAAAAAMBJQJqZmZmZGUdAzczMzMyMS0AAAAAAAEBGQGZmZmZmZkhAmpmZmZmZR0AAAAAAAAD4f2ZmZmZmZkdAMzMzMzMzSUCamZmZmZlGQDMzMzMz80hA"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Culmen Length (mm)=%{x}\u003cbr\u003eCulmen Depth (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002fNLQJqZmZmZmUdAzczMzMyMSEBmZmZmZqZHQGZmZmZmZkdAmpmZmZnZREAzMzMzM7NKQGZmZmZmpkVAzczMzMwMSEAAAAAAAEBJQGZmZmZm5khAAAAAAADARUAAAAAAAMBJQJqZmZmZGUdAzczMzMyMS0AAAAAAAEBGQGZmZmZmZkhAmpmZmZmZR0AAAAAAAAD4f2ZmZmZmZkdAMzMzMzMzSUCamZmZmZlGQDMzMzMz80hA"},"xaxis":"x2","y":{"dtype":"f8","bdata":"..."},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Culmen Length (mm)=%{x}\u003cbr\u003eCulmen Depth (mm)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"...\u002fNLQJqZmZmZmUdAzczMzMyMSEBmZmZmZqZHQGZmZmZmZkdAmpmZmZnZREAzMzMzM7NKQGZmZmZmpkVAzczMzMwMSEAAAAAAAEBJQGZmZmZm5khAAAAAAADARUAAAAAAAMBJQJqZmZmZGUdAzczMzMyMS0AAAAAAAEBGQGZmZmZmZkhAmpmZmZmZR0AAAAAAAAD4f2ZmZmZmZkdAMzMzMzMzSUCamZmZmZlGQDMzMzMz80hA"},"xaxis":"x3","y":{"dtype":"f8","bdata":"..."},"yaxis":"y3","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %% [markdown]
# ### Layering multiple plots

# %% [markdown]
# #### Population dataset

# %%
world_bank_population = pd.read_csv(os.path.join(path_to_raw_data, file_world_bank_population))

df_population = world_bank_population.copy()

# %%
# df_population.describe()
# df_population.info()
df_population.head()
# Out:
#      Country Name Country Code        Series Name  Series Code 1960 [YR1960]  \
# 0  Afghanistan     AFG          Population, total  SP.POP.TOTL  8996973
# 1  Albania         ALB          Population, total  SP.POP.TOTL  1608800
# 2  Algeria         DZA          Population, total  SP.POP.TOTL  11057863
# 3  American Samoa  ASM          Population, total  SP.POP.TOTL  20123
# 4  Andorra         AND          Population, total  SP.POP.TOTL  13411
#
#   1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  \
# 0  9169410       9351441       9543205       9744781       9956320
# 1  1659800       1711319       1762621       1814135       1864791
# 2  11336339      11619828      11912803      12221675      12550885
# 3  20602         21253         22034         22854         23672
# 4  14375         15370         16412         17469         18549
#
#   1966 [YR1966] 1967 [YR1967] 1968 [YR1968] 1969 [YR1969] 1970 [YR1970]  \
# 0  10174836      10399926      10637063      10893776      11173642
# 1  1914573       1965598       2022272       2081695       2135479
# 2  12902627      13275026      13663583      14061722      14464985
# 3  24462         25248         25989         26703         27363
# 4  19647         20758         21890         23058         24276
#
#   1971 [YR1971] 1972 [YR1972] 1973 [YR1973] 1974 [YR1974] 1975 [YR1975]  \
# 0  11475445      11791215      12108963      12412950      12689160
# 1  2187853       2243126       2296752       2350124       2404831
# 2  14872250      15285990      15709825      16149025      16607707
# 3  27984         28567         29100         29596         30052
# 4  25559         26892         28232         29520         30705
#
#   1976 [YR1976] 1977 [YR1977] 1978 [YR1978] 1979 [YR1979] 1980 [YR1980]  \
# 0  12943093      13171306      13341198      13411056      13356511
# 1  2458526       2513546       2566266       2617832       2671997
# 2  17085801      17582904      18102266      18647815      19221665
# 3  30456         30838         31269         31845         32646
# 4  31777         32771         33737         34818         36067
#
#   1981 [YR1981] 1982 [YR1982] 1983 [YR1983] 1984 [YR1984] 1985 [YR1985]  \
# 0  13171673      12882528      12537730      12204292      11938208
# 1  2726056       2784278       2843960       2904429       2964762
# 2  19824301      20452902      21101875      21763575      22431502
# 3  33701         34968         36412         37946         39519
# 4  37500         39114         40867         42706         44600
#
#   1986 [YR1986] 1987 [YR1987] 1988 [YR1988] 1989 [YR1989] 1990 [YR1990]  \
# 0  11736179      11604534      11618005      11868877      12412308
# 1  3022635       3083605       3142336       3227943       3286542
# 2  23102389      23774284      24443467      25106190      25758869
# 3  41119         42740         44343         45894         47347
# 4  46517         48455         50434         52448         54509
#
#   1991 [YR1991] 1992 [YR1992] 1993 [YR1993] 1994 [YR1994] 1995 [YR1995]  \
# 0  13299017      14485546      15816603      17075727      18110657
# 1  3266790       3247039       3227287       3207536       3187784
# 2  26400479      27028326      27635515      28213774      28757785
# 3  48685         49896         51020         52095         53161
# 4  56671         58888         60971         62677         63850
#
#   1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999] 2000 [YR2000]  \
# 0  18853437      19357126      19737765      20170844      20779953
# 1  3168033       3148281       3128530       3108778       3089027
# 2  29266405      29742979      30192754      30623406      31042235
# 3  54211         55221         56171         57053         57821
# 4  64360         64327         64142         64370         65390
#
#   2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  \
# 0  21606988      22600770      23680871      24726684      25654277
# 1  3060173       3051010       3039616       3026939       3011487
# 2  31451514      31855109      32264157      32692163      33149724
# 3  58494         59080         59504         59681         59562
# 4  67341         70049         73182         76244         78867
#
#   2006 [YR2006] 2007 [YR2007] 2008 [YR2008] 2009 [YR2009] 2010 [YR2010]  \
# 0  26433049      27100536      27722276      28394813      29185507
# 1  2992547       2970017       2947314       2927519       2913021
# 2  33641002      34166972      34730608      35333881      35977455
# 3  59107         58365         57492         56683         56079
# 4  80993         82684         83862         84463         84449
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# 0  30117413      31161376      32269589      33370794      34413603
# 1  2905195       2900401       2895092       2889104       2880703
# 2  36661444      37383887      38140132      38923687      39728025
# 3  55759         55667         55713         55791         55812
# 4  83747         82427         80774         79213         78011
#
#   2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]  \
# 0  35383128      36296400      37172386      38041754      38928000
# 1  2876101       2873457       2866376       2854191       2850000
# 2  40551404      41389198      42228429      43053054      43851000
# 3  55741         55620         55465         55312         55000
# 4  77297         77001         77006         77142         77000
#
#   2021 [YR2021] 2022 [YR2022] 2023 [YR2023] 2024 [YR2024] 2025 [YR2025]  \
# 0  39835000      40754000      41681000      42609000      43532000
# 1  2844000       2837000       2828000       2820000       2811000
# 2  44617000      45350000      46053000      46731000      47388000
# 3  55000         55000         55000         55000         55000
# 4  77000         77000         78000         78000         78000
#
#   2026 [YR2026] 2027 [YR2027] 2028 [YR2028] 2029 [YR2029] 2030 [YR2030]  \
# 0  44449000      45364000      46275000      47185000      48094000
# 1  2802000       2792000       2782000       2771000       2761000
# 2  48022000      48634000      49226000      49801000      50361000
# 3  55000         55000         55000         55000         55000
# 4  78000         78000         78000         78000         78000
#
#   2031 [YR2031] 2032 [YR2032] 2033 [YR2033] 2034 [YR2034] 2035 [YR2035]  \
# 0  49000000      49904000      50804000      51699000      52587000
# 1  2749000       2737000       2723000       2709000       2694000
# 2  50908000      51444000      51971000      52494000      53016000
# 3  55000         55000         55000         55000         55000
# 4  78000         78000         78000         78000         78000
#
#   2036 [YR2036] 2037 [YR2037] 2038 [YR2038] 2039 [YR2039] 2040 [YR2040]  \
# 0  53469000      54343000      55209000      56065000      56912000
# 1  2678000       2660000       2642000       2623000       2603000
# 2  53537000      54059000      54583000      55110000      55640000
# 3  54000         54000         54000         54000         54000
# 4  78000         78000         78000         78000         78000
#
#   2041 [YR2041] 2042 [YR2042] 2043 [YR2043] 2044 [YR2044] 2045 [YR2045]  \
# 0  57748000      58574000      59387000      60188000      60974000
# 1  2583000       2562000       2542000       2520000       2499000
# 2  56174000      56711000      57250000      57789000      58326000
# 3  54000         54000         54000         54000         54000
# 4  78000         78000         78000         77000         77000
#
#   2046 [YR2046] 2047 [YR2047] 2048 [YR2048] 2049 [YR2049] 2050 [YR2050]
# 0  61746000      62503000      63245000      63972000      64683000
# 1  2477000       2456000       2434000       2412000       2390000
# 2  58859000      59388000      59911000      60423000      60923000
# 3  54000         54000         54000         54000         54000
# 4  77000         77000         77000         76000         76000

# %% [markdown]
# Remove part of column name

# %%
# colomn bames to not change
column_names_not_split = ['Country Name', 'Country Code', 'Series Name',  'Series Code']

# Create the new list of column names by splitting if not in the list of names to keep
new_column_names = []
for col in df_population.columns:
    if col not in column_names_not_split:
        new_column_names.append(col.split(' ')[0])
    else:
        new_column_names.append(col.lower().replace(' ', '_')) # Apply string operations here

df_population.columns = new_column_names

df_population.sample(5)
# Out:
#                  country_name country_code        series_name  series_code  \
# 166  Netherlands               NLD          Population, total  SP.POP.TOTL
# 228  Switzerland               CHE          Population, total  SP.POP.TOTL
# 133  Libya                     LBY          Population, total  SP.POP.TOTL
# 191  Pre-demographic dividend  PRE          Population, total  SP.POP.TOTL
# 29   Brunei Darussalam         BRN          Population, total  SP.POP.TOTL
#
#           1960       1961       1962       1963       1964       1965  \
# 166  11486631   11638712   11805689   11965966   12127120   12294732
# 228  5327827    5434294    5573815    5694247    5789228    5856472
# 133  1448417    1498071    1550813    1607171    1667825    1733306
# 191  187617091  191889701  196349224  200997724  205835453  210864985
# 29   81702      85562      89481      93540      97812      102386
#
#           1966       1967       1968       1969       1970       1971  \
# 166  12456251   12598201   12729721   12877984   13038526   13194497
# 228  5918002    5991785    6067714    6136387    6180877    6213399
# 133  1803683    1878877    1958914    2043818    2133526    2228146
# 191  216096098  221539671  227201434  233086769  239204902  245537549
# 29   107274     112448     117898     123600     129529     135671
#
#           1972       1973       1974       1975       1976       1977  \
# 166  13328593   13439322   13545056   13666335   13774037   13856185
# 228  6260956    6307347    6341405    6338632    6302504    6281174
# 133  2327490    2430755    2536888    2645139    2754696    2865637
# 191  252097524  258953043  266195005  273877851  282049515  290664899
# 29   142022     148512     155072     161626     168181     174714
#
#           1978       1979       1980       1981       1982       1983  \
# 166  13941700   14038270   14149800   14247208   14312690   14367070
# 228  6281738    6294365    6319408    6354074    6391309    6418773
# 133  2979093    3096729    3219466    3347781    3480454    3614689
# 191  299569965  308551448  317462492  326257657  335003787  343806020
# 29   181205     187604     193879     200021     206065     212076
#
#           1984       1985       1986       1987       1988       1989  \
# 166  14424211   14491632   14572278   14665037   14760094   14848907
# 228  6441865    6470365    6504124    6545106    6593386    6646912
# 133  3746715    3873781    3994597    4109725    4220450    4328939
# 191  352822108  362177640  371878676  381918512  392393097  403416160
# 29   218175     224449     230915     237563     244404     251458
#
#           1990       1991       1992       1993       1994       1995  \
# 166  14951510   15069798   15184166   15290368   15382838   15459006
# 228  6715519    6799978    6875364    6938265    6993795    7040687
# 133  4436661    4544242    4650885    4755133    4854875    4948798
# 191  415057375  427398511  440397767  453849633  467465199  481049511
# 29   258721     266210     273892     281681     289454     297114
#
#           1996       1997       1998       1999       2000       2001  \
# 166  15530498   15610650   15707209   15812088   15925513   16046180
# 228  7071850    7088906    7110001    7143991    7184250    7229854
# 133  5036171    5118007    5196780    5275926    5357891    5443248
# 191  494517676  507968946  521617674  535773390  550660001  566366102
# 29   304622     311958     319144     326210     333165     340034
#
#           2002       2003       2004       2005       2006       2007  \
# 166  16148929   16225302   16281779   16319868   16346101   16381696
# 228  7284753    7339001    7389625    7437115    7483934    7551117
# 133  5531089    5620547    5710154    5798614    5886872    5974787
# 191  582828705  599938109  617518671  635451653  653695022  672318833
# 29   346782     353293     359433     365114     370263     374965
#
#           2008       2009       2010       2011       2012       2013  \
# 166  16445593   16530388   16615394   16693074   16754962   16804432
# 228  7647675    7743831    7824909    7912398    7996861    8089346
# 133  6058748    6133984    6197663    6247439    6285750    6320359
# 191  691447610  711257522  731868772  753326798  775573001  798495530
# 29   379421     383906     388646     393688     398989     404421
#
#           2014       2015       2016       2017       2018       2019  \
# 166  16865008   16939923   17030314   17131296   17231624   17332850
# 228  8188649    8282396    8373338    8451840    8514329    8574832
# 133  6362037    6418315    6492164    6580724    6678567    6777452
# 191  821931240  845759344  869943914  894512725  919485393  944902749
# 29   409769     414907     419800     424473     428962     433285
#
#           2020       2021        2022        2023        2024        2025  \
# 166  17368000   17405000   17442000    17477000    17510000    17540000
# 228  8633000    8689000    8744000     8798000     8850000     8901000
# 133  6871000    6959000    7041000     7119000     7194000     7268000
# 191  970795000  997156000  1023976000  1051257000  1079019000  1107264000
# 29   437000     442000     445000      449000      453000      456000
#
#            2026        2027        2028        2029        2030        2031  \
# 166  17566000    17588000    17607000    17622000    17634000    17643000
# 228  8951000     8999000     9045000     9089000     9131000     9172000
# 133  7340000     7410000     7477000     7543000     7606000     7668000
# 191  1135995000  1165207000  1194888000  1225031000  1255612000  1286630000
# 29   459000      463000      466000      468000      471000      473000
#
#            2032        2033        2034        2035        2036        2037  \
# 166  17650000    17654000    17655000    17654000    17649000    17641000
# 228  9210000     9248000     9284000     9318000     9352000     9384000
# 133  7728000     7785000     7842000     7897000     7950000     8003000
# 191  1318075000  1349923000  1382153000  1414748000  1447686000  1480957000
# 29   476000      478000      480000      482000      483000      485000
#
#            2038        2039        2040        2041        2042        2043  \
# 166  17630000    17616000    17599000    17578000    17554000    17527000
# 228  9414000     9443000     9471000     9497000     9522000     9546000
# 133  8053000     8103000     8151000     8197000     8242000     8286000
# 191  1514541000  1548424000  1582586000  1617010000  1651678000  1686578000
# 29   486000      488000      489000      490000      491000      491000
#
#            2044        2045        2046        2047        2048        2049  \
# 166  17498000    17466000    17431000    17395000    17357000    17318000
# 228  9568000     9589000     9609000     9628000     9646000     9664000
# 133  8327000     8366000     8403000     8437000     8469000     8499000
# 191  1721685000  1756980000  1792445000  1828068000  1863842000  1899746000
# 29   492000      492000      493000      493000      493000      493000
#
#            2050
# 166  17277000
# 228  9681000
# 133  8525000
# 191  1935786000
# 29   492000

# %% [markdown]
# Remove rows with `country_code` NULL

# %%
df_population.shape
df_population = df_population[~df_population['country_code'].isnull() == True]
df_population.shape
# Out:
# (264, 95)
# (259, 95)

# %%
df_population.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Cleaning the data before converting data types

# %%
columns_objects = ['country_name', 'country_code', 'series_name',  'series_code']
mask = ~df_population.columns.isin(columns_objects)
columns_to_change_dtype = df_population.columns[mask]

# %% [markdown]
# If you just want to see which values are causing trouble

# %%
for col in columns_to_change_dtype:
    bad = df_population[~df_population[col].apply(lambda x: isinstance(x, (int, float, str, type(None))))]
    if not bad.empty:
        print(f"Problematic entries in column {col}:")
        print(bad[col])

# %%
def clean_value(val):
    # Try to convert, otherwise return pd.NA
    try:
        return int(val)
    except (ValueError, TypeError):
        return pd.NA

for col in columns_to_change_dtype:
    df_population[col] = df_population[col].apply(clean_value).astype('Int64')

# %% [markdown]
# #### Plot layered charts

# %%
df_population.tail()
# Out:
#            country_name country_code        series_name  series_code  \
# 254  West Bank and Gaza  PSE          Population, total  SP.POP.TOTL
# 255  World               WLD          Population, total  SP.POP.TOTL
# 256  Yemen, Rep.         YEM          Population, total  SP.POP.TOTL
# 257  Zambia              ZMB          Population, total  SP.POP.TOTL
# 258  Zimbabwe            ZWE          Population, total  SP.POP.TOTL
#
#            1960        1961        1962        1963        1964        1965  \
# 254  <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 255  3031437775  3072480998  3125456671  3190564032  3256064767  3322973367
# 256  5315355     5393036     5473671     5556766     5641597     5727751
# 257  3070776     3164329     3260650     3360104     3463213     3570464
# 258  3776681     3905034     4039201     4178726     4322861     4471177
#
#            1966        1967        1968        1969        1970        1971  \
# 254  <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 255  3393031801  3462460201  3532826854  3607499991  3682911039  3760509002
# 256  5816247     5907874     6001852     6097035     6193384     6290365
# 257  3681955     3797873     3918872     4045740     4179067     4319224
# 258  4623351     4779827     4941906     5111337     5289303     5476982
#
#            1972        1973        1974        1975        1976        1977  \
# 254  <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 255  3836892580  3912347640  3988478324  4062864562  4135418002  4207766711
# 256  6390574     6500816     6629999     6784695     6967941     7178675
# 257  4466174     4619546     4778724     4943283     5112823     5287548
# 258  5673911     5877726     6085074     6293875     6502569     6712827
#
#            1978        1979        1980        1981        1982        1983  \
# 254  <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 255  4281312782  4356746035  4432925590  4511137170  4592341169  4674266079
# 256  7414158     7669694     7941898     8231910     8541605     8869370
# 257  5468262     5656139     5851825     6055366     6265864     6481916
# 258  6929664     7160023     7408624     7675591     7958241     8254747
#
#            1984        1985        1986        1987        1988        1989  \
# 254  <NA>        <NA>        <NA>        <NA>        <NA>        <NA>
# 255  4755914211  4839074592  4924736807  5012555212  5101297281  5189996799
# 256  9213084     9572175     9941109     10322043    10730862    11189177
# 257  6701540     6923149     7146969     7372837     7598275     7820205
# 258  8562249     8877489     9200149     9527203     9849125     10153852
#
#            1990        1991        1992        1993        1994        1995  \
# 254  1978248     2068845     2163591     2262676     2366298     2474666
# 255  5280076284  5368065408  5452349932  5537511534  5621787194  5706689090
# 256  11709993    12302124    12954155    13634076    14297613    14913315
# 257  8036845     8246656     8451347     8656486     8869740     9096607
# 258  10432421    10680995    10900502    11092766    11261744    11410714
#
#            1996        1997        1998        1999        2000        2001  \
# 254  2587997     2706518     2776568     2848431     2922153     2997784
# 255  5789623839  5872254361  5954005524  6034491778  6114332536  6193671787
# 256  15469274    15975668    16450310    16921149    17409072    17918373
# 257  9339733     9597609     9866476     10140561    10415944    10692193
# 258  11541217    11653242    11747072    11822719    11881477    11923914
#
#            2002        2003        2004        2005        2006        2007  \
# 254  3075373     3154969     3236626     3320396     3406334     3494496
# 255  6272752974  6351882361  6431551644  6511748367  6592734542  6674203658
# 256  18443691    18985000    19540098    20107409    20687646    21282515
# 257  10971698    11256743    11550642    11856247    12173514    12502958
# 258  11954290    11982224    12019912    12076699    12155491    12255922
#
#            2008        2009        2010        2011        2012        2013  \
# 254  3591977     3689099     3786161     3882986     3979998     4076708
# 255  6756917904  6839574284  6921871614  7002860604  7085763408  7169640142
# 256  21892146    22516460    23154855    23807588    24473178    25147109
# 257  12848530    13215139    13605984    14023193    14465121    14926504
# 258  12379549    12526968    12697723    12894316    13115131    13350356
#
#            2014        2015        2016        2017      2018        2019  \
# 254  4173398     4270092     4367088     4454805     4569087   4685306
# 255  7254228377  7338964960  7424282488  7509065705  <NA>      7673533972
# 256  25823485    26497889    27168210    27834821    28498687  29161922
# 257  15399753    15879361    16363507    16853688    17351822  17861030
# 258  13586681    13814629    14030390    14236745    14439018  14645468
#
#            2020        2021        2022        2023        2024        2025  \
# 254  4800000     4916000     5031000     5148000     5264000     5380000
# 255  7753402000  7832616000  7910901000  7988218000  8064538000  8139909000
# 256  29826000    30491000    31155000    31818000    32480000    33140000
# 257  18384000    18921000    19470000    20033000    20608000    21197000
# 258  14863000    15092000    15331000    15581000    15841000    16110000
#
#            2026        2027        2028        2029        2030        2031  \
# 254  5497000     5615000     5732000     5850000     5968000     6086000
# 255  8214269000  8287618000  8359941000  8431223000  8501464000  8570653000
# 256  33798000    34454000    35107000    35758000    36407000    37053000
# 257  21798000    22412000    23039000    23677000    24326000    24985000
# 258  16390000    16680000    16979000    17285000    17596000    17912000
#
#            2032        2033        2034        2035        2036        2037  \
# 254  6204000     6323000     6442000     6560000     6679000     6798000
# 255  8638767000  8705772000  8771680000  8836518000  8900288000  8963040000
# 256  37696000    38336000    38972000    39603000    40229000    40850000
# 257  25655000    26335000    27024000    27722000    28429000    29144000
# 258  18233000    18557000    18883000    19212000    19542000    19873000
#
#            2038        2039        2040        2041        2042        2043  \
# 254  6916000     7034000     7152000     7269000     7386000     7502000
# 255  9024750000  9085413000  9145007000  9203505000  9260895000  9317139000
# 256  41464000    42071000    42670000    43260000    43842000    44413000
# 257  29867000    30599000    31338000    32086000    32841000    33604000
# 258  20205000    20535000    20864000    21190000    21514000    21835000
#
#            2044        2045        2046        2047        2048        2049  \
# 254  7617000     7732000     7846000     7959000     8072000     8183000
# 255  9372199000  9426057000  9478673000  9530075000  9580243000  9629176000
# 256  44974000    45523000    46060000    46585000    47096000    47595000
# 257  34373000    35149000    35931000    36719000    37514000    38314000
# 258  22152000    22465000    22772000    23075000    23372000    23663000
#
#            2050
# 254  8294000
# 255  9676527000
# 256  48080000
# 257  39121000
# 258  23948000

# %%
# df_population['country_name'].to_list()

# %%
df_north_am_population = df_population[df_population['country_name'].isin(['North America'])][columns_to_change_dtype].sum().reset_index()
df_north_am_population.columns = ['year', 'population']
df_north_am_population.head()

df_eu_population = df_population[df_population['country_name'].isin(['European Union'])][columns_to_change_dtype].sum().reset_index()
df_eu_population.columns = ['year', 'population']
df_eu_population.head()
# Out:
#    year  population
# 0  1960  198624409
# 1  1961  202007500
# 2  1962  205198600
# 3  1963  208253700
# 4  1964  211262900
#    year  population
# 0  1960  356906076
# 1  1961  359998418
# 2  1962  363200473
# 3  1963  366516491
# 4  1964  369850244

# %%
# Combine traces from both figures
layered_fig = Figure()

bar_fig = px.bar(df_north_am_population,
                 x='year',
                 y='population')
line_fig = px.line(df_eu_population,
                   x='year',
                   y='population',
                   color_discrete_sequence=['red'])

layered_fig = Figure(
    data=[*bar_fig.data, *line_fig.data]
)
layered_fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="3452ba42-c4b5-422a-81a9-83aa46fab391" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3452ba42-c4b5-422a-81a9-83aa46fab391")) {                    Plotly.newPlot(                        "3452ba42-c4b5-422a-81a9-83aa46fab391",                        [{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030","2031","2032","2033","2034","2035","2036","2037","2038","2039","2040","2041","2042","2043","2044","2045","2046","2047","2048","2049","2050"],"xaxis":"x","y":{"dtype":"i4","bdata":"mcTWC8xjCgwIFTsMBLNpDLSdlwz82sEMOPTpDEBcEA0Y3jMNmEpWDRgQfw1AmrAN15zWDTF++Q1p\u002fRsO+25BDtiTZQ5DbIsOS9iyDogs3A6JFwIPZe8oDycDTw8tTHMPXP+VD6aeuQ\u002fkRd8PanYFEGZ1LBB+RFcQGGKIEMHmwBDz5fsQkqQ0EX9nahH5G58RG1zTEdWqCRJkQj4Sa6JyEpagphKJk9YS+EkEE\u002faCLhPdM1wTejSKE7nluhOgQusTlWkcFIwZSxS\u002fvXcUPvGeFNpdxxQm\u002f+0UPZ0WFWxIPhVYqmcVnXeNFaJJrxVfFM8VOAPwFeCYERaw1DIWqLZTFlBSdBboxpQWoAy1FlAA1RZwjvQW6LoTF1iVMheQJVEXmEBvF3i7jBdQZ6kXmDDFF5gL4BfwB\u002foXKDkTGECfKxioUUMYGFxaGADWcBgwx4YY6E6cGJiEsRggl8YYIJbbGFCN8Bg4kAUZCBoaGQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030","2031","2032","2033","2034","2035","2036","2037","2038","2039","2040","2041","2042","2043","2044","2045","2046","2047","2048","2049","2050"],"xaxis":"x","y":{"dtype":"i4","bdata":"XPRFFdIjdRXZ\u002f6UVC5nYFYR3CxYcBzwWz+ZpFlnUlRZD1r4Wj6\u002fmFtzRBhchZCYXJxxOFwG2dBdNtZkXIdS9F5G93heShvwXmLIYGC3cMxgMsU8YPERpGOPEfRgUO44Y79ScGIP8qxgRkL0YIEPQGDPh5BiEjPoYG\u002fwPGd0YIxm06jUZiu5KGVQTWxnPWGcZ3+1xGYq2exkncIQZhTSPGfAIlxnMr58ZmLyuGcMkxhms7d4Z\u002fXP2GaEPDBowfyIaQvw3GijfRxr8P1Ea4ENFGtwqTxpfjF8aV3FwGg8zfxpwmo0aSWyXGklJoRrpfawaMJurGuDjqBpokqQamCufGtjxmBrIcZIaiHyLGqj6gxrQ0HsaaMRyGuDsaBo4Sl4aOA9TGqAcRxqwkToa2IUtGkjxHxqI5xEaQE0DGnAi9BmoT+QZiOTTGUDZwhkwHrEZWLOeGeiQixmAxncZ2F9jGfBcThkI3TgZuCAiGQ=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choro ...

# %%
df_poor_population = df_population[df_population['country_name'].isin(['Heavily indebted poor countries (HIPC)'])][columns_to_change_dtype].sum().reset_index()
df_poor_population.columns = ['year', 'population']
df_poor_population.head()
# Out:
#    year  population
# 0  1960  161734357
# 1  1961  165573152
# 2  1962  169567094
# 3  1963  173722855
# 4  1964  178048171

# %%
line_fig2 = px.line(df_poor_population,
                   x='year',
                   y='population',
                   color_discrete_sequence=['green'])


layered_fig = Figure(
    data=[*bar_fig.data, *line_fig.data, *line_fig2.data]
)
layered_fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="3fa47dd1-6a88-46c3-a8cb-aa521e1190ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3fa47dd1-6a88-46c3-a8cb-aa521e1190ef")) {                    Plotly.newPlot(                        "3fa47dd1-6a88-46c3-a8cb-aa521e1190ef",                        [{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030","2031","2032","2033","2034","2035","2036","2037","2038","2039","2040","2041","2042","2043","2044","2045","2046","2047","2048","2049","2050"],"xaxis":"x","y":{"dtype":"i4","bdata":"mcTWC8xjCgwIFTsMBLNpDLSdlwz82sEMOPTpDEBcEA0Y3jMNmEpWDRgQfw1AmrAN15zWDTF++Q1p\u002fRsO+25BDtiTZQ5DbIsOS9iyDogs3A6JFwIPZe8oDycDTw8tTHMPXP+VD6aeuQ\u002fkRd8PanYFEGZ1LBB+RFcQGGKIEMHmwBDz5fsQkqQ0EX9nahH5G58RG1zTEdWqCRJkQj4Sa6JyEpagphKJk9YS+EkEE\u002faCLhPdM1wTejSKE7nluhOgQusTlWkcFIwZSxS\u002fvXcUPvGeFNpdxxQm\u002f+0UPZ0WFWxIPhVYqmcVnXeNFaJJrxVfFM8VOAPwFeCYERaw1DIWqLZTFlBSdBboxpQWoAy1FlAA1RZwjvQW6LoTF1iVMheQJVEXmEBvF3i7jBdQZ6kXmDDFF5gL4BfwB\u002foXKDkTGECfKxioUUMYGFxaGADWcBgwx4YY6E6cGJiEsRggl8YYIJbbGFCN8Bg4kAUZCBoaGQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030","2031","2032","2033","2034","2035","2036","2037","2038","2039","2040","2041","2042","2043","2044","2045","2046","2047","2048","2049","2050"],"xaxis":"x","y":{"dtype":"i4","bdata":"XPRFFdIjdRXZ\u002f6UVC5nYFYR3CxYcBzwWz+ZpFlnUlRZD1r4Wj6\u002fmFtzRBhchZCYXJxxOFwG2dBdNtZkXIdS9F5G93heShvwXmLIYGC3cMxgMsU8YPERpGOPEfRgUO44Y79ScGIP8qxgRkL0YIEPQGDPh5BiEjPoYG\u002fwPGd0YIxm06jUZiu5KGVQTWxnPWGcZ3+1xGYq2exkncIQZhTSPGfAIlxnMr58ZmLyuGcMkxhms7d4Z\u002fXP2GaEPDBowfyIaQvw3GijfRxr8P1Ea4ENFGtwqTxpfjF8aV3FwGg8zfxpwmo0aSWyXGklJoRrpfawaMJurGuDjqBpokqQamCufGtjxmBrIcZIaiHyLGqj6gxrQ0HsaaMRyGuDsaBo4Sl4aOA9TGqAcRxqwkToa2IUtGkjxHxqI5xEaQE0DGnAi9BmoT+QZiOTTGUDZwhkwHrEZWLOeGeiQixmAxncZ2F9jGfBcThkI3TgZuCAiGQ=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986"," ...

# %% [markdown]
# Variant to add additional plot to Figure

# %%
layered_fig = Figure(
    data=[*bar_fig.data, *line_fig.data]
)

layered_fig.add_trace(line_fig2.data[0])

#  add annotation - ?
current_year = dict(
    x=2025, y=200000, text="Current year: 2025",
    font=dict(color="black"), showarrow=True, arrowhead=4
)

# Add a title
layered_fig.update_layout(title='Population of Noth America vs EU vs Poor Contries')

layered_fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="a872701e-a267-454a-b863-b6c2b4c4a147" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a872701e-a267-454a-b863-b6c2b4c4a147")) {                    Plotly.newPlot(                        "a872701e-a267-454a-b863-b6c2b4c4a147",                        [{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030","2031","2032","2033","2034","2035","2036","2037","2038","2039","2040","2041","2042","2043","2044","2045","2046","2047","2048","2049","2050"],"xaxis":"x","y":{"dtype":"i4","bdata":"mcTWC8xjCgwIFTsMBLNpDLSdlwz82sEMOPTpDEBcEA0Y3jMNmEpWDRgQfw1AmrAN15zWDTF++Q1p\u002fRsO+25BDtiTZQ5DbIsOS9iyDogs3A6JFwIPZe8oDycDTw8tTHMPXP+VD6aeuQ\u002fkRd8PanYFEGZ1LBB+RFcQGGKIEMHmwBDz5fsQkqQ0EX9nahH5G58RG1zTEdWqCRJkQj4Sa6JyEpagphKJk9YS+EkEE\u002faCLhPdM1wTejSKE7nluhOgQusTlWkcFIwZSxS\u002fvXcUPvGeFNpdxxQm\u002f+0UPZ0WFWxIPhVYqmcVnXeNFaJJrxVfFM8VOAPwFeCYERaw1DIWqLZTFlBSdBboxpQWoAy1FlAA1RZwjvQW6LoTF1iVMheQJVEXmEBvF3i7jBdQZ6kXmDDFF5gL4BfwB\u002foXKDkTGECfKxioUUMYGFxaGADWcBgwx4YY6E6cGJiEsRggl8YYIJbbGFCN8Bg4kAUZCBoaGQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030","2031","2032","2033","2034","2035","2036","2037","2038","2039","2040","2041","2042","2043","2044","2045","2046","2047","2048","2049","2050"],"xaxis":"x","y":{"dtype":"i4","bdata":"XPRFFdIjdRXZ\u002f6UVC5nYFYR3CxYcBzwWz+ZpFlnUlRZD1r4Wj6\u002fmFtzRBhchZCYXJxxOFwG2dBdNtZkXIdS9F5G93heShvwXmLIYGC3cMxgMsU8YPERpGOPEfRgUO44Y79ScGIP8qxgRkL0YIEPQGDPh5BiEjPoYG\u002fwPGd0YIxm06jUZiu5KGVQTWxnPWGcZ3+1xGYq2exkncIQZhTSPGfAIlxnMr58ZmLyuGcMkxhms7d4Z\u002fXP2GaEPDBowfyIaQvw3GijfRxr8P1Ea4ENFGtwqTxpfjF8aV3FwGg8zfxpwmo0aSWyXGklJoRrpfawaMJurGuDjqBpokqQamCufGtjxmBrIcZIaiHyLGqj6gxrQ0HsaaMRyGuDsaBo4Sl4aOA9TGqAcRxqwkToa2IUtGkjxHxqI5xEaQE0DGnAi9BmoT+QZiOTTGUDZwhkwHrEZWLOeGeiQixmAxncZ2F9jGfBcThkI3TgZuCAiGQ=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"year=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986"," ...

# %% [markdown]
# ###<mark>Time Buttons</mark>

# %% [markdown]
# #### Load the `rain` dataset

# %%
rain = pd.read_csv(os.path.join(path_to_raw_data, file_rain))

df_rain = rain.copy()

# %%
df_rain.head()
df_rain.info()
df_rain.describe()
# Out:
#      Date  Rainfall
# 0  1/1/20  0.0
# 1  2/1/20  0.2
# 2  3/1/20  0.0
# 3  4/1/20  0.0
# 4  5/1/20  0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      305 non-null    object
#  1   Rainfall  305 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.9+ KB
#          Rainfall
# count  305.000000
# mean   4.430820
# std    14.993195
# min    0.000000
# 25%    0.000000
# 50%    0.000000
# 75%    2.200000
# max    187.000000

# %%
df_rain['Date'] = pd.to_datetime(df_rain['Date']).dt.date
# Out:
# /tmp/ipython-input-2169384052.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
df_rain.head()
df_rain.sample(5)
df_rain.tail()

df_rain['Date'].min()
df_rain['Date'].max()
# Out:
#          Date  Rainfall
# 0  2020-01-01  0.0
# 1  2020-02-01  0.2
# 2  2020-03-01  0.0
# 3  2020-04-01  0.0
# 4  2020-05-01  0.0
#            Date  Rainfall
# 148  2020-05-28  0.0
# 30   2020-01-31  0.0
# 73   2020-03-14  0.0
# 119  2020-04-29  2.2
# 223  2020-11-08  2.2
#            Date  Rainfall
# 300  2020-10-27  13.6
# 301  2020-10-28  0.0
# 302  2020-10-29  15.3
# 303  2020-10-30  0.0
# 304  2020-10-31  2.8
# datetime.date(2020, 1, 1)
# datetime.date(2020, 12, 10)

# %%
df_rain.isna().sum()
df_rain.duplicated().sum()
# Out:
# Date        0
# Rainfall    0
# dtype: int64
# np.int64(0)

# %%
df_rain = df_rain.sort_values(by='Date').reset_index(drop=True)

# %%
date_buttons = [
    {'count': 48, 'label': "48HR", 'step': "hour", 'stepmode': "todate"},
    {'count': 28, 'label': "4WTD", 'step': "day", 'stepmode': "todate"},
    {'count': 4, 'label': "4MTD", 'step': "month", 'stepmode': "todate"},
    {'count': 1, 'label': "YTD", 'step': "year", 'stepmode': "todate"}]

# %%
# Create the line chart
fig = px.line(df_rain, x='Date', y='Rainfall',
              title= "Rainfall (mm)")

# Add the buttons
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=date_buttons
        ),
        type='date'  # Explicitly set axis type
    )
)

fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="92747f46-08a2-40a6-b360-d5382cb91a29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("92747f46-08a2-40a6-b360-d5382cb91a29")) {                    Plotly.newPlot(                        "92747f46-08a2-40a6-b360-d5382cb91a29",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eRainfall=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-01","2020-01-02","2020-01-03","2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-13","2020-01-14","2020-01-15","2020-01-16","2020-01-17","2020-01-18","2020-01-19","2020-01-20","2020-01-21","2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-01","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-01","2020-07-02","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-01","2020-08-02","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-13","2020-09-14","2 ...

# %% [markdown]
# ##<mark>Advanced Interactivity</mark>

# %% [markdown]
# ### Custom Buttons

# %%
revenue2 = pd.read_csv(os.path.join(path_to_raw_data, file_revenue_data2))
                            #  ,encoding='ISO-8859-1') # or use that: encoding='cp1252'

df_revenue_2 = revenue2.copy()

# %%
df_revenue_2.head()
# Out:
#    Rank                   Company Revenue  employees Industry  age
# 0  1     Walmart                   523964  2,300,000  Tech     44
# 1  2     Sinopec Group             407009  71,200     Tech     56
# 2  3     State Grid                383906  377,000    Oil      21
# 3  4     China National Petroleum  379130  123,000    Tech     33
# 4  5     Royal Dutch Shell         352106  260,000    Tech     70

# %%
# my_scale=[
#     ('rgb(242,238,10)')
#     ,('rgb(242,95,10)')
#     ,('rgb(255,0,0)')
# ]

# %%
fig = px.bar(
    data_frame = df_revenue_2
    ,x='Industry'
    ,y='Revenue'
    # ,color_continuous_scale=my_scale
    ,color='Industry'
    # ,height=400
    # ,width=600
    ,title='Revenue by industry'

)
# Change the axis titles
fig.update_layout(
    xaxis=dict(title=dict(text="")),
    yaxis=dict(title=dict(text=""))
)
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="4dd17b8a-78d9-4007-9415-887216905860" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4dd17b8a-78d9-4007-9415-887216905860")) {                    Plotly.newPlot(                        "4dd17b8a-78d9-4007-9415-887216905860",                        [{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tech","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tech","orientation":"v","showlegend":true,"textposition":"auto","x":["Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech"],"xaxis":"x","y":["523964","407009","379130","352106","329784","282760","260174","256776","254616","242155","231051","172869","171474","162754","161857","155900","153566","152703","148984","136866","135940","135091","131868","131244","130359","125843","95096","94758"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"textposition":"auto","x":["Oil","Oil","Oil","Oil","Oil","Oil","Oil","Oil","Oil","Oil"],"xaxis":"x","y":["383906","184280","181193","177069","176249","147313","145534","142422","137332","137237"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pharmaceuticals","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pharmaceuticals","orientation":"v","showlegend":true,"textposition":"auto","x":["Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals"],"xaxis":"x","y":["282616","280522","275288","264938","215111","205839","197705","193346","158884"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Professional Services","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Professional Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services"],"xaxis":"x","y":["179589","146516","104972","104213","103915","103449","102729","100522","98673","97937","97536","96313","95214","93736","92154","92107","90863","90740"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Retail","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Retail","orientation":"v","showlegend":true,"textposition":"auto","x":["Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail"],"xaxis":"x","y":["124813","124316","123324","122286","122071","120304","120302","118009","90615","90135","89907","89647","89417","89347","88862","88357","88257","87440","86990","86270","86163","85905","85058","84049"],"yaxis":"y","type":"bar"},{"hove ...

# %% [markdown]
# #### Create a button to switch plot type

# %%
my_buttons = [
    {'label': 'Bar plot'
    ,'method': 'update'
    ,'args': [{'type': 'bar'}]
    }
    ,{
        'label': 'Scatterplot'
        ,'method': 'update'
        ,'args': [{'type': 'scatter', 'mode': 'markers'}]
    }
]

# %%
# print(fig)
# dir(fig.layout)
# dir(fig.data[0])

# %%
fig.update_layout({
    'updatemenus': [{
        'type': 'buttons'
        ,'direction': 'down'
        ,'x': 1.11
        ,'y': 0.5
        ,'showactive': True
        ,'active': 0
        ,'buttons': my_buttons
        }]
})
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="944de7a1-0b52-4706-aa49-883c0433ba0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("944de7a1-0b52-4706-aa49-883c0433ba0a")) {                    Plotly.newPlot(                        "944de7a1-0b52-4706-aa49-883c0433ba0a",                        [{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tech","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tech","orientation":"v","showlegend":true,"textposition":"auto","x":["Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Tech"],"xaxis":"x","y":["523964","407009","379130","352106","329784","282760","260174","256776","254616","242155","231051","172869","171474","162754","161857","155900","153566","152703","148984","136866","135940","135091","131868","131244","130359","125843","95096","94758"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"textposition":"auto","x":["Oil","Oil","Oil","Oil","Oil","Oil","Oil","Oil","Oil","Oil"],"xaxis":"x","y":["383906","184280","181193","177069","176249","147313","145534","142422","137332","137237"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pharmaceuticals","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pharmaceuticals","orientation":"v","showlegend":true,"textposition":"auto","x":["Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals"],"xaxis":"x","y":["282616","280522","275288","264938","215111","205839","197705","193346","158884"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Professional Services","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Professional Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services"],"xaxis":"x","y":["179589","146516","104972","104213","103915","103449","102729","100522","98673","97937","97536","96313","95214","93736","92154","92107","90863","90740"],"yaxis":"y","type":"bar"},{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Retail","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Retail","orientation":"v","showlegend":true,"textposition":"auto","x":["Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail"],"xaxis":"x","y":["124813","124316","123324","122286","122071","120304","120302","118009","90615","90135","89907","89647","89417","89347","88862","88357","88257","87440","86990","86270","86163","85905","85058","84049"],"yaxis":"y","type":"bar"},{"hove ...

# %%
df_revenue_2.head()
# Out:
#    Rank                   Company Revenue  employees Industry  age
# 0  1     Walmart                   523964  2,300,000  Tech     44
# 1  2     Sinopec Group             407009  71,200     Tech     56
# 2  3     State Grid                383906  377,000    Oil      21
# 3  4     China National Petroleum  379130  123,000    Tech     33
# 4  5     Royal Dutch Shell         352106  260,000    Tech     70

# %%
fig = Figure()

fig.add_trace(px.bar(df_revenue_2, x="Industry", y="Revenue", color_discrete_sequence=['blue']).data[0])
fig.add_trace(px.bar(df_revenue_2, x="Industry", y="age", color_discrete_sequence=['red']).data[0])

value_annotations=[{'text': 'Industry annotation', 'showarrow': True, 'x': 'Retail', 'y': 4000 }]
age_annotations=[{'text': 'Age annotation', 'showarrow': True, 'x': '70', 'y': -6 }]

my_buttons = [
{'label': "By Industry", 'method': "update", 'args': [{}, {"annotations": value_annotations}]},
{'label': "By Company Age", 'method': "update", 'args': [{}, {"annotations": age_annotations}]}]

# Add the buttons
fig.update_layout({
    'updatemenus':[{
            'type': 'buttons',
            'direction': 'down',
            'x': 1.3, 'y': 0.5, 'buttons': my_buttons
            }]})
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="be5158cc-d1aa-434d-85e8-a10fae4b6e20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("be5158cc-d1aa-434d-85e8-a10fae4b6e20")) {                    Plotly.newPlot(                        "be5158cc-d1aa-434d-85e8-a10fae4b6e20",                        [{"hovertemplate":"Industry=%{x}\u003cbr\u003eRevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"blue","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tech","Tech","Oil","Tech","Tech","Tech","Tech","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Tech","Tech","Tech","Tech","Tech","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Pharmaceuticals","Oil","Oil","Professional Services","Oil","Oil","Tech","Tech","Tech","Tech","Pharmaceuticals","Tech","Tech","Tech","Tech","Oil","Professional Services","Oil","Oil","Oil","Oil","Tech","Tech","Tech","Tech","Tech","Tech","Tech","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Legal","Legal","Legal","Legal","Legal","Legal","Legal","Legal","Legal","Legal","Legal","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Tech","Tech","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Retail","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown"],"xaxis":"x","y":["523964","407009","383906","379130","352106","329784","282760","282616","280522","275288","264938","260174","256776","254616","242155","231051","215111","205839","197705","193346","184280","181193","179589","177069","176249","172869","171474","162754","161857","158884","155900","153566","152703","148984","147313","146516","145534","142422","137332","137237","136866","135940","135091","131868","131244","130359","125843","124813","124316","123324","122286","122071","120304","120302","118009","116638","114621","113589","110225","109915","109559","109448","108942","108687","108527","105921","104972","104213","103915","103449","102729","100522","98673","97937","97536","96313","95214","95096","94758","93736","92154","92107","90863","90740","90615","90135","89907","89647","89417","89347","88862","88357","88257","87440","86990","86270","86163","85905","85058","84049","83643","83505","82700","82059","81978","80639","80588","80498","80376","80278","79932","7 ...

# %% [markdown]
# ### Dropdowns in Plotly

# %%
df_penguins.nunique()
# Out:
# Unnamed: 0             344
# studyName              3
# Sample Number          152
# Species                3
# Region                 1
# Island                 3
# Stage                  1
# Individual ID          190
# Clutch Completion      2
# Date Egg               50
# Culmen Length (mm)     164
# Culmen Depth (mm)      80
# Flipper Length (mm)    55
# Body Mass (g)          94
# Sex                    2
# Delta 15 N (o/oo)      330
# Delta 13 C (o/oo)      331
# Comments               10
# dtype: int64

# %%
fig = Figure()

for state in ['MALE', 'FEMALE']:
    df = df_penguins
    fig.add_trace(px.scatter(
        df, x='Body Mass (g)',
        y='Sex').data[0])

dropdown_buttons = [
{'label': "ALL", 'method': "update", 'args': [{"visible": [True, True, True]}, {"title": "Body Mass (g) distribution of ALL penguins"}]},
{'label': "MALE", 'method': "update", 'args': [{"visible": [True, False, False]}, {"title": "Body Mass (g) distribution of MALE penguins"}]},
{'label': "FEMALE", 'method': "update", 'args': [{"visible": [False, True, False]}, {"title": "Body Mass (g) distribution of FEMALE penguins"}]},
]

# Update the figure to add dropdown menu
fig.update_layout({
  		'updatemenus': [
        {'active': 0, 'buttons': dropdown_buttons}
        ]})

# Show the plot
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="e8a3f8fb-f2f3-416c-bbea-1cd7458bc402" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8a3f8fb-f2f3-416c-bbea-1cd7458bc402")) {                    Plotly.newPlot(                        "e8a3f8fb-f2f3-416c-bbea-1cd7458bc402",                        [{"hovertemplate":"Body Mass (g)=%{x}\u003cbr\u003eSex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":["MALE","FEMALE","FEMALE",null,"FEMALE","MALE","FEMALE","MALE",null,null,null,null,"FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE",null,"FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE",null,"MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE",null,"MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE",null,"MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE",null,"MALE","FEMALE",null,"FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE","MALE","FEMALE","FEMALE","MALE","FEMALE","MALE","MALE","FEMALE"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Body Mass (g)=%{x}\u003cbr\u003eSex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":["MALE","FEMALE","FEMALE",null,"FEMALE","MALE","FEMALE","MALE",null,nul ...

# %%
fig = px.histogram(
    data_frame = df_revenue_2
    ,x='Revenue'
    ,nbins=10
    ,histfunc='min'
    # ,color_continuous_scale=my_scale
    # ,height=400
    # ,width=600
    ,title='Minimal Revenue by industry'

)
# fig = Figure()

# for state in ['Legal', 'Oil', 'Pharmaceuticals']:
#     df = df_revenue_agg
#     fig.add_trace(px.bar(df, x='Industry', y='Revenue').data[0])

# dropdown_buttons = [
# {'label': "ALL", 'method': "update", 'args': [{"visible": [True, True, True]}, {"title": "ALL"}]},
# {'label': "Legal", 'method': "update", 'args': [{"visible": [True, False, False]}, {"title": "Legal"}]},
# {'label': "Oil", 'method': "update", 'args': [{"visible": [False, True, False]}, {"title": "Oil"}]},
# {'label': "Pharmaceuticals", 'method': "update", 'args': [{"visible": [False, False, True]}, {"title": "Pharmaceuticals"}]},
# ]

# # Update the figure to add dropdown menu
# fig.update_layout({
#   		'updatemenus': [
#         {'active': 0, 'buttons': dropdown_buttons}
#         ]})

# Show the plot
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="cec9bfea-4d61-47e6-9d4a-849c47123145" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cec9bfea-4d61-47e6-9d4a-849c47123145")) {                    Plotly.newPlot(                        "cec9bfea-4d61-47e6-9d4a-849c47123145",                        [{"bingroup":"x","histfunc":"min","hovertemplate":"Revenue=%{x}\u003cbr\u003emin of None=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"orientation":"v","showlegend":false,"x":["523964","407009","383906","379130","352106","329784","282760","282616","280522","275288","264938","260174","256776","254616","242155","231051","215111","205839","197705","193346","184280","181193","179589","177069","176249","172869","171474","162754","161857","158884","155900","153566","152703","148984","147313","146516","145534","142422","137332","137237","136866","135940","135091","131868","131244","130359","125843","124813","124316","123324","122286","122071","120304","120302","118009","116638","114621","113589","110225","109915","109559","109448","108942","108687","108527","105921","104972","104213","103915","103449","102729","100522","98673","97937","97536","96313","95214","95096","94758","93736","92154","92107","90863","90740","90615","90135","89907","89647","89417","89347","88862","88357","88257","87440","86990","86270","86163","85905","85058","84049","83643","83505","82700","82059","81978","80639","80588","80498","80376","80278","79932","79788","79513","79395","78930","78883","78112","77147","77046","76589","76559","75972","75897","75344","75125","75115","74639","74162","74094","74048","73652","73166","72820","72554","72537","72149","72148","71965","71792","71502","71154","70895","70723","70697","70690","70615","70335","69693","69620","69570","69246","69127","68897","68714","67826","67684","67371","67365","67220","67161","67135","66564","65909","65767","65434","64888","64807","64656","64357","64297","63434","63327","62799","62455","62160","61965","61570","60952","60114","60071","59969","59812","59118","58756","58179","58027","57626","57407","57252","57171","57147","56852","55800","55592","54788","54672","54613","54465","54365","Unknown"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlin ...

# %%
# print(fig)
# dir(fig.layout)
# dir(fig.data[0])

# %%
# penguins = pd.read_csv(os.path.join(path_to_raw_data, file_penguins))
#                             #  ,encoding='ISO-8859-1') # or use that: encoding='cp1252'

# df_penguins = penguins.copy()

# %% [markdown]
# ## End
